# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt

# change path later when dataset is added
nii_path = "data/raw/sample.nii.gz"

print("Notebook ready")

# %%
# This will be used tomorrow
# For now, just checking imports
